# %%
# !pip3 install pytesseract

# %%
from PIL import Image

import pytesseract
import os

# %%
list_of_files =os.listdir("Image_dataset/")

# %%
# Batch processing with a single file containing the list of multiple image file paths

for i in list_of_files:
    print(pytesseract.image_to_string('./Image_Dataset/'+i))

# %%
i = "image00013.jpg"
print(pytesseract.image_to_string('./Image_Dataset/'+i))

# %%
# !pip3install img2table

# %%
from img2table.document import Image
src = "Image_Dataset/image00013.jpg"
image = Image(src, 
              detect_rotation=False)

# %%
print(image)
# Out:
# Image(src='Image_Dataset/image00013.jpg', detect_rotation=False)

# %%
from img2table.ocr import TesseractOCR
from img2table.document import Image

# Instantiation of OCR
ocr = TesseractOCR(n_threads=1, lang="eng")

# Instantiation of document, either an image or a PDF
doc = Image(src)

# Table extraction
extracted_tables = doc.extract_tables(ocr=ocr,
                                      implicit_rows=False,
                                      borderless_tables=False,
                                      min_confidence=50)
# Out:
# tesseract 5.3.4
#  leptonica-1.84.1
#   libgif 5.2.1 : libjpeg 8d (libjpeg-turbo 3.0.0) : libpng 1.6.43 : libtiff 4.6.0 : zlib 1.2.12 : libwebp 1.3.2 : libopenjp2 2.5.2
#  Found AVX512BW
#  Found AVX512F
#  Found AVX512VNNI
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE4.1
#  Found libarchive 3.7.2 zlib/1.2.12 liblzma/5.4.4 bz2lib/1.0.8 liblz4/1.9.4 libzstd/1.5.5
#  Found libcurl/8.4.0 SecureTransport (LibreSSL/3.3.6) zlib/1.2.12 nghttp2/1.58.0

# %%
# Instantiation of OCR
ocr = TesseractOCR(n_threads=1, lang="eng")
src ="Image_Dataset/image00047.jpg"
# Instantiation of document, either an image or a PDF
doc = Image(src)

dest ="ext.csv"
# Extraction of tables and creation of a xlsx file containing tables

doc.to_xlsx(dest=dest,
            ocr=ocr,
            implicit_rows=True,
            borderless_tables=True,
            min_confidence=1)
# Out:
# tesseract 5.3.4
#  leptonica-1.84.1
#   libgif 5.2.1 : libjpeg 8d (libjpeg-turbo 3.0.0) : libpng 1.6.43 : libtiff 4.6.0 : zlib 1.2.12 : libwebp 1.3.2 : libopenjp2 2.5.2
#  Found AVX512BW
#  Found AVX512F
#  Found AVX512VNNI
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE4.1
#  Found libarchive 3.7.2 zlib/1.2.12 liblzma/5.4.4 bz2lib/1.0.8 liblz4/1.9.4 libzstd/1.5.5
#  Found libcurl/8.4.0 SecureTransport (LibreSSL/3.3.6) zlib/1.2.12 nghttp2/1.58.0

# %%
# !pip3 install img2table
# Out:
# ...
#   Using cached img2table-1.2.11-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached polars-0.20.16-cp38-abi3-macosx_10_12_x86_64.whl.metadata (15 kB)
# ...
#   Using cached PyMuPDF-1.24.0-cp311-none-macosx_10_9_x86_64.whl.metadata (3.4 kB)
# ...
#   Using cached XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached PyMuPDFb-1.24.0-py3-none-macosx_10_9_x86_64.whl.metadata (1.4 kB)
# ...
# Using cached img2table-1.2.11-py3-none-any.whl (90 kB)
# Using cached polars-0.20.16-cp38-abi3-macosx_10_12_x86_64.whl (25.4 MB)
# Using cached PyMuPDF-1.24.0-cp311-none-macosx_10_9_x86_64.whl (3.6 MB)
# Using cached PyMuPDFb-1.24.0-py3-none-macosx_10_9_x86_64.whl (30.3 MB)
# Using cached XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 MB 8.9 MB/s eta 0:00:00:00:0100:01
# ...

# %%
import boto3

client = boto3.client('textract')

# %%
from PIL import Image

# Open the image file in binary mode
with open("Image_Dataset/image00013.jpg", "rb") as f:
    # Read the image data as bytes
    image_bytes = f.read()

# %%
esponse = client.analyze_document(Document={'Bytes':image_bytes},FeatureTypes=['TABLES'])

# %%
esponse
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1.0,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 0.0, 'Y': 2.0078574219928313e-11},
#      {'X': 1.0, 'Y': 0.0},
#      {'X': 1.0, 'Y': 1.0},
#      {'X': 0.0, 'Y': 1.0}]},
#    'Id': '735cce50-0a6d-4623-a5b8-44166919a19e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['43a4aa68-7851-4913-b135-38cb6923f7da',
#       'f1538e9a-bcec-4906-a810-6a021b446b92',
#       '5d29fe16-b607-457f-a847-7efa68b65293',
#       '6c20242c-b47a-4f7e-9415-270d907db999',
#       '118e3073-5491-4ae6-adfa-9057b5a7b2ef',
#       'c2f59e56-317e-4ce3-bf6e-145943e296b7',
#       'b5fdb40c-63e9-4758-b73f-66eec94f9d6d',
#       '3976ee09-d4fa-47fc-8d5f-e27e5066818f',
#       '511d9f56-cab0-4503-be46-9d8c4400f42e',
#       '80759a45-a479-4d1c-8b3a-223b0ab1b1d5',
#       '30662da4-235c-44c6-8dcb-ee38fe652469',
# ...

# %%
from img2table.ocr import TextractOCR
from img2table.document import Image
ocr = TextractOCR()

src ="./Image_Dataset/image00016.jpg"
# Instantiation of document, either an image or a PDF
doc = Image(src)

dest = 'ext3.xlsx'

# Extraction of tables and creation of a xlsx file containing tables
doc.to_xlsx(dest=dest,
            ocr=ocr,
            implicit_rows=True,
            borderless_tables=True,
            min_confidence=50)
